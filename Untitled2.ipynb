# %%
import pandas as pd

# %%
t1 = pd.read_csv ("pobre_urbano.csv")

# %%
t1
# Out:
#     Unnamed: 0  Periodo  Incidencia  Brecha  Severidad
# 0        Marzo     2008        25.2     8.4        4.2
# 1        Marzo     2009        23.6     7.9        3.9
# 2        Marzo     2010        22.6     7.4        3.6
# 3        Marzo     2011        21.5     6.8        3.2
# 4        Marzo     2012        16.0     4.9        2.2
# 5        Marzo     2013        17.7     5.2        2.3
# 6        Marzo     2014        16.8     4.9        2.1
# 7        Marzo     2015        15.1     4.5        2.0
# 8        Marzo     2016        16.6     5.9        3.0
# 9        Marzo     2017        15.8     4.7        2.2
# 10       Junio     2007        22.4     7.9        4.1
# 11       Junio     2008        23.3     7.8        3.8
# 12       Junio     2009        21.8     7.3        3.5
# 13       Junio     2010        22.9     8.1        4.1
# 14       Junio     2011        19.3     6.1        2.9
# 15       Junio     2012        15.3     4.7        2.1
# ...

# %%
df1. iloc [0:4 , 0:4]
# Out:
#   Unnamed: 0  Periodo  Incidencia  Brecha
# 0      Marzo     2008        25.2     8.4
# 1      Marzo     2009        23.6     7.9
# 2      Marzo     2010        22.6     7.4
# 3      Marzo     2011        21.5     6.8

# %%
t1. ix [0:3 , "Periodo" : "Brecha"]
# Out:
# C:\Users\Usuario\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#    Periodo  Incidencia  Brecha
# 0     2008        25.2     8.4
# 1     2009        23.6     7.9
# 2     2010        22.6     7.4
# 3     2011        21.5     6.8

# %%
t1.head()
# Out:
#   Unnamed: 0  Periodo  Incidencia  Brecha  Severidad
# 0      Marzo     2008        25.2     8.4        4.2
# 1      Marzo     2009        23.6     7.9        3.9
# 2      Marzo     2010        22.6     7.4        3.6
# 3      Marzo     2011        21.5     6.8        3.2
# 4      Marzo     2012        16.0     4.9        2.2

# %%
t1 = t1[2:]

# %%
t1.shape
# Out:
# (39, 5)

# %%
t1.index
# Out:
# RangeIndex(start=2, stop=41, step=1)

# %%
t1.columns
# Out:
# Index([u'Unnamed: 0', u'Periodo', u'Incidencia', u'Brecha', u'Severidad'], dtype='object')

# %%
t2 = t1.set_index('Periodo')

# %%
t2.head(4)
# Out:
#         Unnamed: 0  Incidencia  Brecha  Severidad
# Periodo
# 2010         Marzo        22.6     7.4        3.6
# 2011         Marzo        21.5     6.8        3.2
# 2012         Marzo        16.0     4.9        2.2
# 2013         Marzo        17.7     5.2        2.3

# %%
datos = t1.drop([],axis= 1)
datos.head()
# Out:
#   Unnamed: 0  Periodo  Incidencia  Brecha  Severidad
# 2      Marzo     2010        22.6     7.4        3.6
# 3      Marzo     2011        21.5     6.8        3.2
# 4      Marzo     2012        16.0     4.9        2.2
# 5      Marzo     2013        17.7     5.2        2.3
# 6      Marzo     2014        16.8     4.9        2.1

# %%
datos.columns = ['Mes','Anios','Incidencia','Brecha','Severidad']
datos.head(6)
# Out:
#      Mes  Anios  Incidencia  Brecha  Severidad
# 2  Marzo   2010        22.6     7.4        3.6
# 3  Marzo   2011        21.5     6.8        3.2
# 4  Marzo   2012        16.0     4.9        2.2
# 5  Marzo   2013        17.7     5.2        2.3
# 6  Marzo   2014        16.8     4.9        2.1
# 7  Marzo   2015        15.1     4.5        2.0

# %%
from bokeh.io import output_notebook, output_file
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="04263734-2318-4842-adbc-84073ecd5678">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, show
vbar = figure(plot_width=350, plot_height=250)
vbar.vbar(x=[22.6,21.5,16.0,17.7], width=1, top=[7.4,6.8,4.9,5.2], color="green")
show(vbar)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="147f1534-c04f-4f66-b510-857ce6b85bcf"></div>
# </div>

# %%
from bokeh.plotting import figure,show
 
x = [2010, 2011, 2012, 2013]
y = [22.6,21.5,16.0,17.7]
fig = figure(plot_width=430, plot_height=250)
fig.line(x, y, line_width=4)
 
show(fig)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4651cd53-1de0-46ea-82d2-34c51e842574"></div>
# </div>
